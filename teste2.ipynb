# %%
import pyautogui
import pyperclip
import time
import numpy as np
import pandas as pd
import openpyxl

# %%
tabela_faturamento = pd.read_excel('controle_faturamento_2022_teste.xlsx')

display(tabela_faturamento)
# Out:
#          NFE DATA DE EMISSÃO DATA DE ENVIO À EMPRESA  \
# 0        1.0      2022-01-03              2022-01-03
# 1        2.0      2022-01-04              2022-01-04
# 2        3.0      2022-01-05              2022-01-05
# 3        4.0      2022-01-05              2022-01-05
# 4        5.0      2022-01-06              2022-01-06
# ...      ...             ...                     ...
# 1048566  NaN             NaT                     NaT
# 1048567  NaN             NaT                     NaT
# 1048568  NaN             NaT                     NaT
# 1048569  NaN             NaT                     NaT
# 1048570  NaN             NaT              2019-06-27
#
#          DATA PREVISTA PARA PAGAMENTO DATA DE VENCIMENTO STATUS DE COBRANÇA  \
# 0                                 NaN         2022-01-18            VENCIDO
# 1                                 NaN         2022-01-19            VENCIDO
# 2                                 NaN         2022-01-20            VENCIDO
# ...

# %%
emissão_total = tabela_faturamento['VALOR DO DEPÓSITO'].sum()
print(emissão_total)
print(tabela_faturamento.info())
# Out:
# 930101.4299999999
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048571 entries, 0 to 1048570
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   NFE                                  1147 non-null   float64
#  1   DATA DE EMISSÃO                      113 non-null    datetime64[ns]
#  2   DATA DE ENVIO À EMPRESA              109 non-null    datetime64[ns]
#  3   DATA PREVISTA PARA PAGAMENTO         0 non-null      float64
#  4   DATA DE VENCIMENTO                   775 non-null    datetime64[ns]
#  5   STATUS DE COBRANÇA                   775 non-null    object
#  6   STATUS DA Nfe                        200 non-null    object
#  7   PROJETO                              113 non-null    object
#  8   C/C                                  113 non-null    object
#  9   VALOR                                113 non-null    float64
# ...

# %%
# deletando as colunas/linhas vazias usando o "dropna ou drop"
# axis = 0 -> linha ou axis = 1 -> coluna

tabela_faturamento = tabela_faturamento.dropna(how = "all", axis = 0)
tabela_faturamento = tabela_faturamento.drop("Unnamed: 20", axis = 1)
print(tabela_faturamento.info())
display(tabela_faturamento)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1148 entries, 0 to 1048570
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   NFE                                  1147 non-null   float64
#  1   DATA DE EMISSÃO                      113 non-null    datetime64[ns]
#  2   DATA DE ENVIO À EMPRESA              109 non-null    datetime64[ns]
#  3   DATA PREVISTA PARA PAGAMENTO         0 non-null      float64
#  4   DATA DE VENCIMENTO                   775 non-null    datetime64[ns]
#  5   STATUS DE COBRANÇA                   775 non-null    object
#  6   STATUS DA Nfe                        200 non-null    object
#  7   PROJETO                              113 non-null    object
#  8   C/C                                  113 non-null    object
#  9   VALOR                                113 non-null    float64
# ...
